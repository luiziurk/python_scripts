# %% [markdown]
# ## Analyze A/B Test Results
#
# This project will assure you have mastered the subjects covered in the statistics lessons.  The hope is to have this project be as comprehensive of these topics as possible.  Good luck!
#
# ## Table of Contents
# - [Introduction](#intro)
# - [Part I - Probability](#probability)
# - [Part II - A/B Test](#ab_test)
# - [Part III - Regression](#regression)
#
#
# <a id='intro'></a>
# ### Introduction
#
# A/B tests are very commonly performed by data analysts and data scientists.  It is important that you get some practice working with the difficulties of these
#
# For this project, you will be working to understand the results of an A/B test run by an e-commerce website.  Your goal is to work through this notebook to help the company understand if they should implement the new page, keep the old page, or perhaps run the experiment longer to make their decision.
#
# **As you work through this notebook, follow along in the classroom and answer the corresponding quiz questions associated with each question.** The labels for each classroom concept are provided for each question.  This will assure you are on the right track as you work through the project, and you can feel more confident in your final submission meeting the criteria.  As a final check, assure you meet all the criteria on the [RUBRIC](https://review.udacity.com/#!/projects/37e27304-ad47-4eb0-a1ab-8c12f60e43d0/rubric).
#
# <a id='probability'></a>
# #### Part I - Probability
#
# To get started, let's import our libraries.

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline
#We are setting the seed to assure you get the same answers on quizzes as we set up
random.seed(42)

# %% [markdown]
# `1.` Now, read in the `ab_data.csv` data. Store it in `df`.  **Use your dataframe to answer the questions in Quiz 1 of the classroom.**
#
# a. Read in the dataset and take a look at the top few rows here:

# %%
df = pd.read_csv('ab_data.csv')
df.head()
# Out:
#    user_id                   timestamp      group landing_page  converted
# 0   851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1   804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2   661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3   853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4   864975  2017-01-21 01:52:26.210827    control     old_page          1

# %% [markdown]
# b. Use the below cell to find the number of rows in the dataset.

# %%
df.shape
# Out:
# (294478, 5)

# %% [markdown]
# c. The number of unique users in the dataset.

# %%
df.user_id.nunique()
# Out:
# 290584

# %% [markdown]
# d. The proportion of users converted.

# %%
df_converted = df.query("converted == 1")
convertion_rate = df_converted.shape[0]/df.shape[0]
convertion_rate
# Out:
# 0.11965919355605512

# %% [markdown]
# e. The number of times the `new_page` and `treatment` don't line up.

# %% [markdown]
# >- **Treatment** is related must be related to the new page<br>
# >- **Control** must be related to the old page

# %%
df[["group","landing_page"]].value_counts()
# Out:
# group      landing_page
# treatment  new_page        145311
# control    old_page        145274
# treatment  old_page          1965
# control    new_page          1928
# dtype: int64

# %%
lined_up = df.query("(group == 'treatment' & landing_page == 'new_page') | (group == 'control' & landing_page == 'old_page')")
miss_lined = df.shape[0]-lined_up.shape[0]
miss_lined
# Out:
# 3893

# %% [markdown]
# f. Do any of the rows have missing values?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 294478 entries, 0 to 294477
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       294478 non-null  int64
#  1   timestamp     294478 non-null  object
#  2   group         294478 non-null  object
#  3   landing_page  294478 non-null  object
#  4   converted     294478 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 11.2+ MB

# %% [markdown]
# > As seen above, no lines have null values

# %% [markdown]
# `2.` For the rows where **treatment** is not aligned with **new_page** or **control** is not aligned with **old_page**, we cannot be sure if this row truly received the new or old page.  Use **Quiz 2** in the classroom to provide how we should handle these rows.
#
# a. Now use the answer to the quiz to create a new dataset that meets the specifications from the quiz.  Store your new dataframe in **df2**.

# %%
df2 = lined_up.copy()
df2.head()
# Out:
#    user_id                   timestamp      group landing_page  converted
# 0   851104  2017-01-21 22:11:48.556739    control     old_page          0
# 1   804228  2017-01-12 08:01:45.159739    control     old_page          0
# 2   661590  2017-01-11 16:55:06.154213  treatment     new_page          0
# 3   853541  2017-01-08 18:28:03.143765  treatment     new_page          0
# 4   864975  2017-01-21 01:52:26.210827    control     old_page          1

# %%
# Double Check all of the correct rows were removed - this should be 0
df2[((df2['group'] == 'treatment') == (df2['landing_page'] == 'new_page')) == False].shape[0]
# Out:
# 0

# %% [markdown]
# `3.` Use **df2** and the cells below to answer questions for **Quiz3** in the classroom.

# %% [markdown]
# a. How many unique **user_id**s are in **df2**?

# %%
print(f"There are {df2.shape[0]} records in df2")
# Out:
# There are 290585 records in df2

# %%
print(f"The number of unique Id's is of {df2.user_id.nunique()} records")
# Out:
# The number of unique Id's is of 290584 records

# %% [markdown]
# b. There is one **user_id** repeated in **df2**.  What is it?

# %%
df2.query("user_id.duplicated()")
# Out:
#       user_id                   timestamp      group landing_page  converted
# 2893   773192  2017-01-14 02:55:59.590927  treatment     new_page          0

# %% [markdown]
# c. What is the row information for the repeat **user_id**?

# %%
df2.query("user_id == 773192")
# Out:
#       user_id                   timestamp      group landing_page  converted
# 1899   773192  2017-01-09 05:37:58.781806  treatment     new_page          0
# 2893   773192  2017-01-14 02:55:59.590927  treatment     new_page          0

# %% [markdown]
# d. Remove **one** of the rows with a duplicate **user_id**, but keep your dataframe as **df2**.

# %%
df2 = df2.drop_duplicates('user_id')
df2.user_id.duplicated().sum()
# Out:
# 0

# %% [markdown]
# `4.` Use **df2** in the below cells to answer the quiz questions related to **Quiz 4** in the classroom.
#
# a. What is the probability of an individual converting regardless of the page they receive?

# %%
overall_convertion_rate = df2.query("converted == 1").shape[0]/df2.shape[0]
print("The total convertion rate is of {0:.3%}.".format(overall_convertion_rate))
# Out:
# The total convertion rate is of 11.960%.

# %% [markdown]
# b. Given that an individual was in the `control` group, what is the probability they converted?

# %%
df_control = df2.query("group == 'control'")
ctrl_convertion_rate = df_control.query("converted == 1").shape[0]/df_control.shape[0]
ctrl_convertion_rate = ctrl_convertion_rate

print("The Control Population convertion rate is of {0:.3%}.".format(ctrl_convertion_rate))
# Out:
# The Control Population convertion rate is of 12.039%.

# %% [markdown]
# c. Given that an individual was in the `treatment` group, what is the probability they converted?

# %%
df_treatment = df2.query("group == 'treatment'")
trtm_convertion_rate = df_treatment.query("converted == 1").shape[0]/df_treatment.shape[0]
trtm_convertion_rate = trtm_convertion_rate

print("The Treatment Population convertion rate is of {0:.3%}.".format(trtm_convertion_rate))
# Out:
# The Treatment Population convertion rate is of 11.881%.

# %%
diff = ctrl_convertion_rate - trtm_convertion_rate
print("The difference of conversion rates between the control and treatment population is of {:.5%}".format(diff))
# Out:
# The difference of conversion rates between the control and treatment population is of 0.15782%

# %% [markdown]
# d. What is the probability that an individual received the new page?

# %%
prob_new_page = df2.query("landing_page == 'new_page'").shape[0]/df2.shape[0]
print("The probability of getting a new page is of {:.3%}".format(prob_new_page))
# Out:
# The probability of getting a new page is of 50.006%

# %% [markdown]
# e. Consider your results from a. through d. above, and explain below whether you think there is sufficient evidence to say that the new treatment page leads to more conversions.

# %% [markdown]
# > **Considering that the probability difference between the old and new pages are less than 1% with almost the same sample size for each side, even with a very thin margin of error, the result is roughtly the same. Thus I don't see any increase in sales with the new page, nor a decrease.
# We need to perform a deeper analysis using other features as input, such as date or country.**

# %% [markdown]
# <a id='ab_test'></a>
# ### Part II - A/B Test
#
# Notice that because of the time stamp associated with each event, you could technically run a hypothesis test continuously as each observation was observed.
#
# However, then the hard question is do you stop as soon as one page is considered significantly better than another or does it need to happen consistently for a certain amount of time?  How long do you run to render a decision that neither page is better than another?
#
# These questions are the difficult parts associated with A/B tests in general.
#
#
# `1.` For now, consider you need to make the decision just based on all the data provided.  If you want to assume that the old page is better unless the new page proves to be definitely better at a Type I error rate of 5%, what should your null and alternative hypotheses be?  You can state your hypothesis in terms of words or in terms of **$p_{old}$** and **$p_{new}$**, which are the converted rates for the old and new pages.

# %% [markdown]
# <center>$H_{0}$: $p_{new}$ = $p_{old}$ = 0.1196<br>$H_{1}$: $p_{new}$ > $p_{old}$</center>

# %% [markdown]
# `2.` Assume under the null hypothesis, $p_{new}$ and $p_{old}$ both have "true" success rates equal to the **converted** success rate regardless of page - that is $p_{new}$ and $p_{old}$ are equal. Furthermore, assume they are equal to the **converted** rate in **ab_data.csv** regardless of the page. <br><br>
#
# Use a sample size for each page equal to the ones in **ab_data.csv**.  <br><br>
#
# Perform the sampling distribution for the difference in **converted** between the two pages over 10,000 iterations of calculating an estimate from the null.  <br><br>
#
# Use the cells below to provide the necessary parts of this simulation.  If this doesn't make complete sense right now, don't worry - you are going to work through the problems below to complete this problem.  You can use **Quiz 5** in the classroom to make sure you are on the right track.<br><br>

# %% [markdown]
# <center>$p_{new}$ = $p_{old}$ = overall_convertion_rate</center>

# %% [markdown]
# a. What is the **convert rate** for $p_{new}$ under the null?

# %%
new_conv = old_conv = overall_convertion_rate

# %%
p_new = new_conv
print(f"p_new under the null is: {p_new} " "or {:.3%}".format(p_new))
# Out:
# p_new under the null is: 0.11959708724499628 or 11.960%

# %% [markdown]
# b. What is the **convert rate** for $p_{old}$ under the null? <br>

# %%
p_old = old_conv
print(f"p_old under the null is: {p_old} " "or {:.3%}".format(p_old))
# Out:
# p_old under the null is: 0.11959708724499628 or 11.960%

# %% [markdown]
# c. What is $n_{new}$?

# %%
n_new = df2.query("landing_page == 'new_page'").shape[0]
n_new
# Out:
# 145310

# %% [markdown]
# d. What is $n_{old}$?

# %%
n_old = df2.query("landing_page != 'new_page'").shape[0]
n_old
# Out:
# 145274

# %% [markdown]
# e. Simulate $n_{new}$ transactions with a convert rate of $p_{new}$ under the null.  Store these $n_{new}$ 1's and 0's in **new_page_converted**.

# %%
new_page_converted = np.random.binomial(1,p_new,n_new )
p_new_sim = new_page_converted.mean()
p_new_sim
# Out:
# 0.12026013350767326

# %% [markdown]
# f. Simulate $n_{old}$ transactions with a convert rate of $p_{old}$ under the null.  Store these $n_{old}$ 1's and 0's in **old_page_converted**.

# %%
old_page_converted = np.random.binomial(1,p_old,n_old)
p_old_sim = old_page_converted.mean()
p_old_sim
# Out:
# 0.12007654501149552

# %% [markdown]
# g. Find $p_{new}$ - $p_{old}$ for your simulated values from part (e) and (f).

# %%
diff_sim = p_new_sim - p_old_sim
diff_sim
# Out:
# 0.0001835884961777362

# %% [markdown]
# h. Simulate 10,000 $p_{new}$ - $p_{old}$ values using this same process similarly to the one you calculated in parts **a. through g.** above.  Store all 10,000 values in a numpy array called **p_diffs**.

# %%
samp = {"old_page":[], "new_page":[], "diff": []}
for i in range(10000):
    new_conv_b = np.random.binomial(1,p_new,n_new)
    new_conv_b = new_conv_b.mean()
    old_conv_b = np.random.binomial(1,p_old,n_old)
    old_conv_b = old_conv_b.mean()
    diff_s = new_conv_b - old_conv_b
    samp["old_page"].append(old_conv_b)
    samp["new_page"].append(new_conv_b)
    samp["diff"].append(diff_s)

# %%
samp2 = {"old_page":[], "new_page":[], "diff": []}
for i in range(10000):
    print(f"Running the sample {i}", flush=True)
    b_samp = df2.sample(df2.shape[0], replace = True)
    print(f"Splitting the sample ", flush=True)
    b_new = b_samp.query("landing_page == 'new_page'")
    b_old = b_samp.query("landing_page != 'new_page'")
    print(f"Calculating the rates ", flush=True)
    b_new_rate = b_new.converted.mean()
    b_old_rate = b_old.converted.mean()
    print(f"Calculatingt the difference", flush=True)
    d_diff = b_new_rate - b_old_rate
    print(f"Appendending the {i} data", flush=True)
    samp2["old_page"].append(b_old_rate)
    samp2["new_page"].append(b_new_rate)
    samp2["diff"].append(d_diff)
# Out:
# Running the sample 0
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 0 data
# Running the sample 1
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 1 data
# Running the sample 2
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 2 data
# Running the sample 3
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 3 data
# Running the sample 4
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 4 data
# Running the sample 5
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 5 data
# Running the sample 6
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 6 data
# Running the sample 7
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 7 data
# Running the sample 8
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 8 data
# Running the sample 9
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 9 data
# Running the sample 10
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 10 data
# Running the sample 11
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 11 data
# Running the sample 12
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 12 data
# Running the sample 13
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 13 data
# Running the sample 14
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 14 data
# Running the sample 15
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 15 data
# Running the sample 16
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 16 data
# Running the sample 17
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 17 data
# Running the sample 18
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 18 data
# Running the sample 19
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 19 data
# Running the sample 20
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 20 data
# Running the sample 21
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 21 data
# Running the sample 22
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 22 data
# Running the sample 23
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 23 data
# Running the sample 24
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 24 data
# Running the sample 25
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 25 data
# Running the sample 26
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 26 data
# Running the sample 27
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 27 data
# Running the sample 28
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 28 data
# Running the sample 29
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 29 data
# Running the sample 30
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 30 data
# Running the sample 31
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 31 data
# Running the sample 32
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 32 data
# Running the sample 33
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 33 data
# Running the sample 34
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 34 data
# Running the sample 35
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 35 data
# Running the sample 36
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 36 data
# Running the sample 37
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 37 data
# Running the sample 38
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 38 data
# Running the sample 39
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 39 data
# Running the sample 40
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 40 data
# Running the sample 41
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 41 data
# Running the sample 42
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 42 data
# Running the sample 43
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 43 data
# Running the sample 44
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 44 data
# Running the sample 45
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 45 data
# Running the sample 46
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 46 data
# Running the sample 47
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 47 data
# Running the sample 48
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 48 data
# Running the sample 49
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 49 data
# Running the sample 50
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 50 data
# Running the sample 51
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 51 data
# Running the sample 52
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 52 data
# Running the sample 53
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 53 data
# Running the sample 54
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 54 data
# Running the sample 55
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 55 data
# Running the sample 56
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 56 data
# Running the sample 57
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 57 data
# Running the sample 58
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 58 data
# Running the sample 59
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 59 data
# Running the sample 60
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 60 data
# Running the sample 61
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 61 data
# Running the sample 62
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 62 data
# Running the sample 63
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 63 data
# Running the sample 64
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 64 data
# Running the sample 65
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 65 data
# Running the sample 66
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 66 data
# Running the sample 67
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 67 data
# Running the sample 68
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 68 data
# Running the sample 69
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 69 data
# Running the sample 70
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 70 data
# Running the sample 71
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 71 data
# Running the sample 72
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 72 data
# Running the sample 73
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 73 data
# Running the sample 74
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 74 data
# Running the sample 75
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 75 data
# Running the sample 76
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 76 data
# Running the sample 77
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 77 data
# Running the sample 78
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 78 data
# Running the sample 79
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 79 data
# Running the sample 80
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 80 data
# Running the sample 81
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 81 data
# Running the sample 82
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 82 data
# Running the sample 83
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 83 data
# Running the sample 84
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 84 data
# Running the sample 85
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 85 data
# Running the sample 86
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 86 data
# Running the sample 87
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 87 data
# Running the sample 88
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 88 data
# Running the sample 89
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 89 data
# Running the sample 90
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 90 data
# Running the sample 91
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 91 data
# Running the sample 92
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 92 data
# Running the sample 93
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 93 data
# Running the sample 94
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 94 data
# Running the sample 95
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 95 data
# Running the sample 96
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 96 data
# Running the sample 97
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 97 data
# Running the sample 98
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 98 data
# Running the sample 99
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 99 data
# Running the sample 100
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 100 data
# Running the sample 101
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 101 data
# Running the sample 102
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 102 data
# Running the sample 103
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 103 data
# Running the sample 104
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 104 data
# Running the sample 105
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 105 data
# Running the sample 106
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 106 data
# Running the sample 107
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 107 data
# Running the sample 108
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 108 data
# Running the sample 109
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 109 data
# Running the sample 110
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 110 data
# Running the sample 111
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 111 data
# Running the sample 112
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 112 data
# Running the sample 113
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 113 data
# Running the sample 114
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 114 data
# Running the sample 115
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 115 data
# Running the sample 116
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 116 data
# Running the sample 117
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 117 data
# Running the sample 118
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 118 data
# Running the sample 119
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 119 data
# Running the sample 120
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 120 data
# Running the sample 121
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 121 data
# Running the sample 122
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 122 data
# Running the sample 123
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 123 data
# Running the sample 124
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 124 data
# Running the sample 125
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 125 data
# Running the sample 126
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 126 data
# Running the sample 127
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 127 data
# Running the sample 128
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 128 data
# Running the sample 129
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 129 data
# Running the sample 130
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 130 data
# Running the sample 131
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 131 data
# Running the sample 132
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 132 data
# Running the sample 133
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 133 data
# Running the sample 134
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 134 data
# Running the sample 135
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 135 data
# Running the sample 136
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 136 data
# Running the sample 137
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 137 data
# Running the sample 138
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 138 data
# Running the sample 139
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 139 data
# Running the sample 140
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 140 data
# Running the sample 141
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 141 data
# Running the sample 142
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 142 data
# Running the sample 143
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 143 data
# Running the sample 144
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 144 data
# Running the sample 145
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 145 data
# Running the sample 146
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 146 data
# Running the sample 147
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 147 data
# Running the sample 148
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 148 data
# Running the sample 149
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 149 data
# Running the sample 150
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 150 data
# Running the sample 151
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 151 data
# Running the sample 152
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 152 data
# Running the sample 153
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 153 data
# Running the sample 154
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 154 data
# Running the sample 155
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 155 data
# Running the sample 156
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 156 data
# Running the sample 157
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 157 data
# Running the sample 158
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 158 data
# Running the sample 159
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 159 data
# Running the sample 160
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 160 data
# Running the sample 161
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 161 data
# Running the sample 162
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 162 data
# Running the sample 163
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 163 data
# Running the sample 164
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 164 data
# Running the sample 165
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 165 data
# Running the sample 166
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 166 data
# Running the sample 167
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 167 data
# Running the sample 168
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 168 data
# Running the sample 169
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 169 data
# Running the sample 170
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 170 data
# Running the sample 171
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 171 data
# Running the sample 172
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 172 data
# Running the sample 173
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 173 data
# Running the sample 174
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 174 data
# Running the sample 175
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 175 data
# Running the sample 176
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 176 data
# Running the sample 177
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 177 data
# Running the sample 178
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 178 data
# Running the sample 179
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 179 data
# Running the sample 180
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 180 data
# Running the sample 181
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 181 data
# Running the sample 182
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 182 data
# Running the sample 183
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 183 data
# Running the sample 184
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 184 data
# Running the sample 185
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 185 data
# Running the sample 186
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 186 data
# Running the sample 187
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 187 data
# Running the sample 188
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 188 data
# Running the sample 189
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 189 data
# Running the sample 190
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 190 data
# Running the sample 191
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 191 data
# Running the sample 192
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 192 data
# Running the sample 193
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 193 data
# Running the sample 194
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 194 data
# Running the sample 195
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 195 data
# Running the sample 196
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 196 data
# Running the sample 197
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 197 data
# Running the sample 198
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 198 data
# Running the sample 199
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 199 data
# Running the sample 200
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 200 data
# Running the sample 201
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 201 data
# Running the sample 202
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 202 data
# Running the sample 203
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 203 data
# Running the sample 204
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 204 data
# Running the sample 205
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 205 data
# Running the sample 206
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 206 data
# Running the sample 207
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 207 data
# Running the sample 208
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 208 data
# Running the sample 209
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 209 data
# Running the sample 210
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 210 data
# Running the sample 211
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 211 data
# Running the sample 212
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 212 data
# Running the sample 213
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 213 data
# Running the sample 214
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 214 data
# Running the sample 215
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 215 data
# Running the sample 216
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 216 data
# Running the sample 217
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 217 data
# Running the sample 218
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 218 data
# Running the sample 219
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 219 data
# Running the sample 220
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 220 data
# Running the sample 221
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 221 data
# Running the sample 222
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 222 data
# Running the sample 223
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 223 data
# Running the sample 224
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 224 data
# Running the sample 225
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 225 data
# Running the sample 226
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 226 data
# Running the sample 227
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 227 data
# Running the sample 228
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 228 data
# Running the sample 229
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 229 data
# Running the sample 230
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 230 data
# Running the sample 231
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 231 data
# Running the sample 232
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 232 data
# Running the sample 233
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 233 data
# Running the sample 234
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 234 data
# Running the sample 235
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 235 data
# Running the sample 236
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 236 data
# Running the sample 237
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 237 data
# Running the sample 238
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 238 data
# Running the sample 239
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 239 data
# Running the sample 240
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 240 data
# Running the sample 241
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 241 data
# Running the sample 242
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 242 data
# Running the sample 243
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 243 data
# Running the sample 244
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 244 data
# Running the sample 245
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 245 data
# Running the sample 246
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 246 data
# Running the sample 247
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 247 data
# Running the sample 248
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 248 data
# Running the sample 249
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 249 data
# Running the sample 250
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 250 data
# Running the sample 251
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 251 data
# Running the sample 252
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 252 data
# Running the sample 253
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 253 data
# Running the sample 254
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 254 data
# Running the sample 255
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 255 data
# Running the sample 256
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 256 data
# Running the sample 257
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 257 data
# Running the sample 258
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 258 data
# Running the sample 259
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 259 data
# Running the sample 260
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 260 data
# Running the sample 261
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 261 data
# Running the sample 262
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 262 data
# Running the sample 263
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 263 data
# Running the sample 264
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 264 data
# Running the sample 265
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 265 data
# Running the sample 266
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 266 data
# Running the sample 267
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 267 data
# Running the sample 268
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 268 data
# Running the sample 269
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 269 data
# Running the sample 270
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 270 data
# Running the sample 271
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 271 data
# Running the sample 272
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 272 data
# Running the sample 273
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 273 data
# Running the sample 274
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 274 data
# Running the sample 275
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 275 data
# Running the sample 276
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 276 data
# Running the sample 277
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 277 data
# Running the sample 278
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 278 data
# Running the sample 279
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 279 data
# Running the sample 280
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 280 data
# Running the sample 281
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 281 data
# Running the sample 282
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 282 data
# Running the sample 283
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 283 data
# Running the sample 284
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 284 data
# Running the sample 285
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 285 data
# Running the sample 286
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 286 data
# Running the sample 287
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 287 data
# Running the sample 288
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 288 data
# Running the sample 289
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 289 data
# Running the sample 290
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 290 data
# Running the sample 291
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 291 data
# Running the sample 292
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 292 data
# Running the sample 293
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 293 data
# Running the sample 294
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 294 data
# Running the sample 295
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 295 data
# Running the sample 296
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 296 data
# Running the sample 297
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 297 data
# Running the sample 298
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 298 data
# Running the sample 299
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 299 data
# Running the sample 300
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 300 data
# Running the sample 301
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 301 data
# Running the sample 302
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 302 data
# Running the sample 303
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 303 data
# Running the sample 304
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 304 data
# Running the sample 305
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 305 data
# Running the sample 306
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 306 data
# Running the sample 307
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 307 data
# Running the sample 308
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 308 data
# Running the sample 309
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 309 data
# Running the sample 310
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 310 data
# Running the sample 311
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 311 data
# Running the sample 312
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 312 data
# Running the sample 313
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 313 data
# Running the sample 314
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 314 data
# Running the sample 315
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 315 data
# Running the sample 316
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 316 data
# Running the sample 317
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 317 data
# Running the sample 318
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 318 data
# Running the sample 319
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 319 data
# Running the sample 320
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 320 data
# Running the sample 321
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 321 data
# Running the sample 322
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 322 data
# Running the sample 323
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 323 data
# Running the sample 324
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 324 data
# Running the sample 325
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 325 data
# Running the sample 326
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 326 data
# Running the sample 327
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 327 data
# Running the sample 328
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 328 data
# Running the sample 329
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 329 data
# Running the sample 330
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 330 data
# Running the sample 331
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 331 data
# Running the sample 332
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 332 data
# Running the sample 333
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 333 data
# Running the sample 334
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 334 data
# Running the sample 335
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 335 data
# Running the sample 336
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 336 data
# Running the sample 337
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 337 data
# Running the sample 338
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 338 data
# Running the sample 339
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 339 data
# Running the sample 340
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 340 data
# Running the sample 341
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 341 data
# Running the sample 342
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 342 data
# Running the sample 343
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 343 data
# Running the sample 344
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 344 data
# Running the sample 345
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 345 data
# Running the sample 346
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 346 data
# Running the sample 347
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 347 data
# Running the sample 348
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 348 data
# Running the sample 349
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 349 data
# Running the sample 350
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 350 data
# Running the sample 351
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 351 data
# Running the sample 352
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 352 data
# Running the sample 353
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 353 data
# Running the sample 354
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 354 data
# Running the sample 355
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 355 data
# Running the sample 356
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 356 data
# Running the sample 357
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 357 data
# Running the sample 358
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 358 data
# Running the sample 359
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 359 data
# Running the sample 360
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 360 data
# Running the sample 361
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 361 data
# Running the sample 362
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 362 data
# Running the sample 363
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 363 data
# Running the sample 364
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 364 data
# Running the sample 365
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 365 data
# Running the sample 366
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 366 data
# Running the sample 367
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 367 data
# Running the sample 368
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 368 data
# Running the sample 369
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 369 data
# Running the sample 370
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 370 data
# Running the sample 371
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 371 data
# Running the sample 372
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 372 data
# Running the sample 373
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 373 data
# Running the sample 374
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 374 data
# Running the sample 375
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 375 data
# Running the sample 376
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 376 data
# Running the sample 377
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 377 data
# Running the sample 378
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 378 data
# Running the sample 379
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 379 data
# Running the sample 380
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 380 data
# Running the sample 381
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 381 data
# Running the sample 382
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 382 data
# Running the sample 383
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 383 data
# Running the sample 384
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 384 data
# Running the sample 385
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 385 data
# Running the sample 386
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 386 data
# Running the sample 387
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 387 data
# Running the sample 388
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 388 data
# Running the sample 389
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 389 data
# Running the sample 390
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 390 data
# Running the sample 391
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 391 data
# Running the sample 392
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 392 data
# Running the sample 393
# Splitting the sample
# Calculating the rates
# Calculatingt the difference
# Appendending the 393 data
# Running the sample 394
# Splitting the sample
# Calculating the rates
# ---------------------------------------------------------------------------
# ...
#       <a href='vscode-notebook-cell:/c%3A/Users/iurkl/OneDrive/Treinamentos/Udacity/Repositories/Datasets/project_3/AnalyzeABTestResults%202/Analyze_ab_test_results_notebook.ipynb#ch0000062?line=6'>7</a> b_old = b_samp.query("landing_page != 'new_page'")
#       <a href='vscode-notebook-cell:/c%3A/Users/iurkl/OneDrive/Treinamentos/Udacity/Repositories/Datasets/project_3/AnalyzeABTestResults%202/Analyze_ab_test_results_notebook.ipynb#ch0000062?line=7'>8</a> print(f"Calculating the rates ")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/iurkl/OneDrive/Treinamentos/Udacity/Repositories/Datasets/project_3/AnalyzeABTestResults%202/Analyze_ab_test_results_notebook.ipynb#ch0000062?line=8'>9</a> b_new_rate = b_new.converted.mean()
#      <a href='vscode-notebook-cell:/c%3A/Users/iurkl/OneDrive/Treinamentos/Udacity/Repositories/Datasets/project_3/AnalyzeABTestResults%202/Analyze_ab_test_results_notebook.ipynb#ch0000062?line=9'>10</a> b_old_rate = b_old.converted.mean()
#      <a href='vscode-notebook-cell:/c%3A/Users/iurkl/OneDrive/Treinamentos/Udacity/Repositories/Datasets/project_3/AnalyzeABTestResults%202/Analyze_ab_test_results_notebook.ipynb#ch0000062?line=10'>11</a> print(f"Calculatingt the difference")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:10751, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10739'>10740</a> @doc(
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10740'>10741</a>     _num_doc,
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10741'>10742</a>     desc="Return the mean of the values over the requested axis.",
#    (...)
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10748'>10749</a> )
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10749'>10750</a> def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10750'>10751</a>     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:10369, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10367'>10368</a> def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10368'>10369</a>     return self._stat_function(
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10369'>10370</a>         "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10370'>10371</a>     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:10354, in NDFrame._stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10343'>10344</a>     warnings.warn(
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10344'>10345</a>         "Using the level keyword in DataFrame and Series aggregations is "
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10345'>10346</a>         "deprecated and will be removed in a future version. Use groupby "
#    (...)
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10348'>10349</a>         stacklevel=4,
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10349'>10350</a>     )
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10350'>10351</a>     return self._agg_by_level(
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10351'>10352</a>         name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10352'>10353</a>     )
# > <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10353'>10354</a> return self._reduce(
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10354'>10355</a>     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/generic.py?line=10355'>10356</a> )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\series.py:4392, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/series.py?line=4387'>4388</a>     raise NotImplementedError(
#    <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/series.py?line=4388'>4389</a>         f"Series.{name} does not implement numeric_only."
#    <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/series.py?line=4389'>4390</a>     )
#    <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/series.py?line=4390'>4391</a> with np.errstate(all="ignore"):
# -> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/series.py?line=4391'>4392</a>     return op(delegate, skipna=skipna, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\nanops.py:93, in disallow.__call__.<locals>._f(*args, **kwargs)
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=90'>91</a> try:
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=91'>92</a>     with np.errstate(invalid="ignore"):
# ---> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=92'>93</a>         return f(*args, **kwargs)
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=93'>94</a> except ValueError as e:
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=94'>95</a>     # we want to transform an object array
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=95'>96</a>     # ValueError message to the more typical TypeError
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=96'>97</a>     # e.g. this is normally a disallowed function on
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=97'>98</a>     # object arrays that contain strings
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=98'>99</a>     if is_object_dtype(args[0]):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\nanops.py:155, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=152'>153</a>         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=153'>154</a> else:
# --> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=154'>155</a>     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=156'>157</a> return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\nanops.py:410, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=406'>407</a> if datetimelike and mask is None:
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=407'>408</a>     mask = isna(values)
# --> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=409'>410</a> result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=411'>412</a> if datetimelike:
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=412'>413</a>     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\nanops.py:665, in nanmean(values, axis, skipna, mask)
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=661'>662</a>     dtype_count = dtype
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=663'>664</a> count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=664'>665</a> the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=666'>667</a> if axis is not None and getattr(the_sum, "ndim", False):
#     <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/pandas/core/nanops.py?line=667'>668</a>     count = cast(np.ndarray, count)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\core\_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/numpy/core/_methods.py?line=45'>46</a> def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/numpy/core/_methods.py?line=46'>47</a>          initial=_NoValue, where=True):
# ---> <a href='file:///c%3A/Users/iurkl/AppData/Local/Packages/PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0/LocalCache/local-packages/Python39/site-packages/numpy/core/_methods.py?line=47'>48</a>     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:

# %%
df2.converted.mean()

# %%
p_diffs = np.array(samp['diff'])

# %% [markdown]
# i. Plot a histogram of the **p_diffs**.  Does this plot look like what you expected?  Use the matching problem in the classroom to assure you fully understand what was computed here.

# %%
plt.hist(p_diffs);

# %% [markdown]
# j. What proportion of the **p_diffs** are greater than the actual difference observed in **ab_data.csv**?

# %%
(p_diffs > diff).mean()

# %% [markdown]
# k. In words, explain what you just computed in part **j.**  What is this value called in scientific studies?  What does this value mean in terms of whether or not there is a difference between the new and old pages?

# %% [markdown]
# **Put your answer here.**

# %% [markdown]
# l. We could also use a built-in to achieve similar results.  Though using the built-in might be easier to code, the above portions are a walkthrough of the ideas that are critical to correctly thinking about statistical significance. Fill in the below to calculate the number of conversions for each page, as well as the number of individuals who received each page. Let `n_old` and `n_new` refer the the number of rows associated with the old page and new pages, respectively.

# %%
import statsmodels.api as sm

convert_old = 
convert_new = 
n_old = 
n_new =

# %% [markdown]
# m. Now use `stats.proportions_ztest` to compute your test statistic and p-value.  [Here](http://knowledgetack.com/python/statsmodels/proportions_ztest/) is a helpful link on using the built in.

# %% [markdown]
# n. What do the z-score and p-value you computed in the previous question mean for the conversion rates of the old and new pages?  Do they agree with the findings in parts **j.** and **k.**?

# %% [markdown]
# **Put your answer here.**

# %% [markdown]
# <a id='regression'></a>
# ### Part III - A regression approach
#
# `1.` In this final part, you will see that the result you acheived in the previous A/B test can also be acheived by performing regression.<br><br>
#
# a. Since each row is either a conversion or no conversion, what type of regression should you be performing in this case?

# %% [markdown]
# **Put your answer here.**

# %% [markdown]
# b. The goal is to use **statsmodels** to fit the regression model you specified in part **a.** to see if there is a significant difference in conversion based on which page a customer receives.  However, you first need to create a column for the intercept, and create a dummy variable column for which page each user received.  Add an **intercept** column, as well as an **ab_page** column, which is 1 when an individual receives the **treatment** and 0 if **control**.

# %% [markdown]
# c. Use **statsmodels** to import your regression model.  Instantiate the model, and fit the model using the two columns you created in part **b.** to predict whether or not an individual converts.

# %% [markdown]
# d. Provide the summary of your model below, and use it as necessary to answer the following questions.

# %% [markdown]
# e. What is the p-value associated with **ab_page**? Why does it differ from the value you found in **Part II**?<br><br>  **Hint**: What are the null and alternative hypotheses associated with your regression model, and how do they compare to the null and alternative hypotheses in the **Part II**?

# %% [markdown]
# **Put your answer here.**

# %% [markdown]
# f. Now, you are considering other things that might influence whether or not an individual converts.  Discuss why it is a good idea to consider other factors to add into your regression model.  Are there any disadvantages to adding additional terms into your regression model?

# %% [markdown]
# **Put your answer here.**

# %% [markdown]
# g. Now along with testing if the conversion rate changes for different pages, also add an effect based on which country a user lives. You will need to read in the **countries.csv** dataset and merge together your datasets on the approporiate rows.  [Here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.join.html) are the docs for joining tables.
#
# Does it appear that country had an impact on conversion?  Don't forget to create dummy variables for these country columns - **Hint: You will need two columns for the three dummy variables.** Provide the statistical output as well as a written response to answer this question.

# %%
countries_df = pd.read_csv('./countries.csv')
df_new = countries_df.set_index('user_id').join(df2.set_index('user_id'), how='inner')

# %%
### Create the necessary dummy variables

# %% [markdown]
# h. Though you have now looked at the individual factors of country and page on conversion, we would now like to look at an interaction between page and country to see if there significant effects on conversion.  Create the necessary additional columns, and fit the new model.
#
# Provide the summary results, and your conclusions based on the results.

# %%
### Fit Your Linear Model And Obtain the Results

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# Congratulations on completing the project!
#
# ### Gather Submission Materials
#
# Once you are satisfied with the status of your Notebook, you should save it in a format that will make it easy for others to read. You can use the __File -> Download as -> HTML (.html)__ menu to save your notebook as an .html file. If you are working locally and get an error about "No module name", then open a terminal and try installing the missing module using `pip install <module_name>` (don't include the "<" or ">" or any words following a period in the module name).
#
# You will submit both your original Notebook and an HTML or PDF copy of the Notebook for review. There is no need for you to include any data files with your submission. If you made reference to other websites, books, and other resources to help you in solving tasks in the project, make sure that you document them. It is recommended that you either add a "Resources" section in a Markdown cell at the end of the Notebook report, or you can include a `readme.txt` file documenting your sources.
#
# ### Submit the Project
#
# When you're ready, click on the "Submit Project" button to go to the project submission page. You can submit your files as a .zip archive or you can link to a GitHub repository containing your project files. If you go with GitHub, note that your submission will be a snapshot of the linked repository at time of submission. It is recommended that you keep each project in a separate repository to avoid any potential confusion: if a reviewer gets multiple folders representing multiple projects, there might be confusion regarding what project is to be evaluated.
#
# It can take us up to a week to grade the project, but in most cases it is much faster. You will get an email once your submission has been reviewed. If you are having any problems submitting your project or wish to check on the status of your submission, please email us at dataanalyst-project@udacity.com. In the meantime, you should feel free to continue on with your learning journey by beginning the next module in the program.
