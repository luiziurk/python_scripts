# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./data/fuel_econ.csv')

# %%
df.displ.describe()
# Out:
# count    3929.000000
# mean        2.950573
# std         1.305901
# min         0.600000
# 25%         2.000000
# 50%         2.500000
# 75%         3.600000
# max         7.000000
# Name: displ, dtype: float64

# %%
bins_x = np.arange(0.6, 7+0.3,0.3 )
bins_x
# Out:
# array([0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. , 3.3, 3.6, 3.9, 4.2,
#        4.5, 4.8, 5.1, 5.4, 5.7, 6. , 6.3, 6.6, 6.9, 7.2])

# %%
k = pd.cut(df['displ'], bins_x, right = False, include_lowest=False, labels = False)
k[7]
# Out:
# 4

# %%
df['displ']
# Out:
# 0       3.8
# 1       2.0
# 2       3.6
# 3       3.6
# 4       2.4
#        ...
# 3924    1.8
# 3925    2.0
# 3926    2.0
# 3927    3.4
# 3928    3.4
# Name: displ, Length: 3929, dtype: float64

# %%
df.loc[7]
# Out:
# id                      32214
# make                  Hyundai
# model           Genesis Coupe
# year                     2013
# VClass        Subcompact Cars
# drive        Rear-Wheel Drive
# trans         Automatic 8-spd
# fuelType     Premium Gasoline
# cylinders                   4
# displ                     2.0
# pv2                        89
# pv4                         0
# city                   17.446
# UCity                 21.7946
# highway               26.6295
# UHighway              37.6731
# comb                  20.6507
# co2                       432
# feScore                     5
# ghgScore                    5
# Name: 7, dtype: object

# %%
df
# Out:
#          id        make             model  year           VClass  \
# 0     32204      Nissan              GT-R  2013  Subcompact Cars
# 1     32205  Volkswagen                CC  2013     Compact Cars
# 2     32206  Volkswagen                CC  2013     Compact Cars
# 3     32207  Volkswagen        CC 4motion  2013     Compact Cars
# 4     32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...     ...         ...               ...   ...              ...
# 3924  39882      Toyota       Prius Prime  2018     Midsize Cars
# 3925  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 3926  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 3927  39900       Lexus            LS 500  2018     Midsize Cars
# 3928  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                   drive                             trans          fuelType  \
# 0       All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...
